# %%
import os
import pandas as pd
import numpy as np
import datetime
import requests
import warnings

import matplotlib.pyplot as plt
import matplotlib
import matplotlib.dates as mdates
import seaborn as sns
#import squarify
import plotly.offline as py
#import plotly_express as px

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# set working directory
os.chdir("D:/DSBA-Python/Rework/Reference/Covid")

# read the data file
age_details = pd.read_csv('AgeGroupDetails.csv')
india_covid_19 = pd.read_csv('covid_19_india.csv')
hospital_beds = pd.read_csv('HospitalBedsIndia.csv')
individual_details = pd.read_csv('IndividualDetails.csv')
ICMR_labs = pd.read_csv('ICMRTestingLabs.csv')
state_testing = pd.read_csv('StatewiseTestingDetails.csv')
population = pd.read_csv('population_india_census2011.csv')

confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
recovered_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
latest_data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-04-2020.csv')

india_covid_19['Date'] = pd.to_datetime(india_covid_19['Date'],dayfirst = True)
state_testing['Date'] = pd.to_datetime(state_testing['Date'])

# %%
labels = list(age_details['AgeGroup'])
sizes = list(age_details['TotalCases'])

explode = []

for i in labels:
    explode.append(0.05)
    
plt.figure(figsize= (10,5))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=9, explode =explode)
centre_circle = plt.Circle((0,0),0.70,fc='white')

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Age Group Distribution',fontsize = 20)
plt.axis('equal')  
plt.tight_layout()

# %%
labels = ['Male', 'Female']
sizes = []
sizes.append(list(individual_details['gender'].value_counts())[0])
sizes.append(list(individual_details['gender'].value_counts())[1])

explode = (0.1, 0)
colors = ['#66b3ff','#ff9999']

plt.figure(figsize= (10,5))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90)

plt.title('Gender Distribution (Ignoring the Missing Values)',fontsize = 20)
plt.axis('equal')
plt.tight_layout()

# %%
dates = list(confirmed_df.columns[4:])
dates = list(pd.to_datetime(dates))
dates_india = dates[8:]

# %%
df1 = confirmed_df.groupby('Country/Region').sum().reset_index()
df2 = deaths_df.groupby('Country/Region').sum().reset_index()
df3 = recovered_df.groupby('Country/Region').sum().reset_index()

k = df1[df1['Country/Region']=='India'].loc[:,'1/30/20':]
india_confirmed = k.values.tolist()[0] 

k = df2[df2['Country/Region']=='India'].loc[:,'1/30/20':]
india_deaths = k.values.tolist()[0] 

k = df3[df3['Country/Region']=='India'].loc[:,'1/30/20':]
india_recovered = k.values.tolist()[0] 

plt.figure(figsize= (10,5))
plt.xticks(rotation = 90 ,fontsize = 11)
plt.yticks(fontsize = 10)
plt.xlabel("Dates",fontsize = 20)
plt.ylabel('Total cases',fontsize = 20)
plt.title("Total Confirmed, Active, Death" , fontsize = 20)

ax1 = plt.plot_date(y= india_confirmed,x= dates_india,label = 'Confirmed',linestyle ='-',color = 'b')
ax2 = plt.plot_date(y= india_recovered,x= dates_india,label = 'Recovered',linestyle ='-',color = 'g')
ax3 = plt.plot_date(y= india_deaths,x= dates_india,label = 'Death',linestyle ='-',color = 'r')
plt.legend();

# %%
state_cases = india_covid_19.groupby('State/UnionTerritory')['Confirmed','Deaths','Cured'].max().reset_index()

#state_cases = state_cases.astype({'Deaths': 'int'})
state_cases['Active'] = state_cases['Confirmed'] - (state_cases['Deaths']+state_cases['Cured'])
state_cases["Death Rate (per 100)"] = np.round(100*state_cases["Deaths"]/state_cases["Confirmed"],2)
state_cases["Cure Rate (per 100)"] = np.round(100*state_cases["Cured"]/state_cases["Confirmed"],2)
state_cases.sort_values('Confirmed', ascending= False).fillna(0).style.background_gradient(cmap='Blues',subset=["Confirmed"])\
                        .background_gradient(cmap='Blues',subset=["Deaths"])\
                        .background_gradient(cmap='Blues',subset=["Cured"])\
                        .background_gradient(cmap='Blues',subset=["Active"])\
                        .background_gradient(cmap='Blues',subset=["Death Rate (per 100)"])\
                        .background_gradient(cmap='Blues',subset=["Cure Rate (per 100)"])
# Out:
# <style  type="text/css" >
#     #T_98081b62_d32b_11ea_9703_18dbf25b0573row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row0_col5 {
#             background-color:  #084c95;
#             color:  #f1f1f1;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row0_col6 {
#             background-color:  #3585bf;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row1_col1 {
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row1_col2 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row1_col3 {
#             background-color:  #2979b9;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row1_col4 {
#             background-color:  #97c6df;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row1_col5 {
#             background-color:  #95c5df;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row1_col6 {
#             background-color:  #115ca5;
#             color:  #f1f1f1;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row2_col1 {
#             background-color:  #abd0e6;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row2_col2 {
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row2_col3 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row2_col4 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row2_col5 {
#             background-color:  #2777b8;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row2_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row3_col1 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row3_col2 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row3_col3 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row3_col4 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row3_col5 {
#             background-color:  #c7dbef;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row3_col6 {
#             background-color:  #65aad4;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row4_col1 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row4_col2 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row4_col3 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row4_col4 {
#             background-color:  #7cb7da;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row4_col5 {
#             background-color:  #77b5d9;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row4_col6 {
#             background-color:  #89bedc;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row5_col1 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row5_col2 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row5_col3 {
#             background-color:  #d2e3f3;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row5_col4 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row5_col5 {
#             background-color:  #6fb0d7;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row5_col6 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row6_col1 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row6_col2 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row6_col3 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row6_col4 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row6_col5 {
#             background-color:  #56a0ce;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row6_col6 {
#             background-color:  #1f6eb3;
#             color:  #f1f1f1;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row7_col1 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row7_col2 {
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row7_col3 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row7_col4 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row7_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row7_col6 {
#             background-color:  #125ea6;
#             color:  #f1f1f1;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row8_col1 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row8_col2 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row8_col3 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row8_col4 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row8_col5 {
#             background-color:  #cee0f2;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row8_col6 {
#             background-color:  #105ba4;
#             color:  #f1f1f1;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row9_col1 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row9_col2 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row9_col3 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row9_col4 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row9_col5 {
#             background-color:  #cee0f2;
#             color:  #000000;
#         }    #T_98081b62_d32b_11ea_9703_18dbf25b0573row9_col6 {
#             background-color:  #0e58a2;
#             color:  #f1f1f1;

# %%
hospital_beds =hospital_beds.drop([36])
cols_object = list(hospital_beds.columns[2:8])

for cols in cols_object:
    hospital_beds[cols] = hospital_beds[cols].astype(int,errors = 'ignore')

# %%
top_10_primary = hospital_beds.nlargest(10,'NumPrimaryHealthCenters_HMIS')
top_10_community = hospital_beds.nlargest(10,'NumCommunityHealthCenters_HMIS')
top_10_district_hospitals = hospital_beds.nlargest(10,'NumDistrictHospitals_HMIS')
top_10_public_facility = hospital_beds.nlargest(10,'TotalPublicHealthFacilities_HMIS')
top_10_public_beds = hospital_beds.nlargest(10,'NumPublicBeds_HMIS')

plt.figure(figsize=(15,10))
plt.suptitle('Top 10 States in each Health Facility',fontsize=20)
plt.subplot(221)
plt.title('Primary Health Centers')
plt.barh(top_10_primary['State/UT'],top_10_primary['NumPrimaryHealthCenters_HMIS'],color ='#87479d');

plt.subplot(222)
plt.title('Community Health Centers')
plt.barh(top_10_community['State/UT'],top_10_community['NumCommunityHealthCenters_HMIS'],color = '#9370db');

plt.subplot(224)
plt.title('Total Public Health Facilities')
plt.barh(top_10_community['State/UT'],top_10_public_facility['TotalPublicHealthFacilities_HMIS'],color='#9370db');

plt.subplot(223)
plt.title('District Hospitals')
plt.barh(top_10_community['State/UT'],top_10_district_hospitals['NumDistrictHospitals_HMIS'],color = '#87479d');

# %%
values = list(ICMR_labs['state'].value_counts())
names = list(ICMR_labs['state'].value_counts().index)

plt.figure(figsize=(15,10))
sns.set_color_codes("pastel")
plt.title('ICMR Testing Centers in each State', fontsize = 20)
sns.barplot(x= values, y= names,color = '#9370db');
