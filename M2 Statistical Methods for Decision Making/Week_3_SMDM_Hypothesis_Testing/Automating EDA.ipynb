# %%
import pandas as pd
from pandas_profiling import ProfileReport
df = pd.read_csv("Survey-1.csv")

# %%
design_report = ProfileReport(df)
design_report.to_file(output_file='pandas_profiling Report Survey-1.html')

# %%
import sweetviz as sv
sweet_report = sv.analyze(df)
sweet_report.show_html('sweet_report Report Survey-1.html')
# Out:
# :FEATURES DONE:                    |█████████████████████| [100%]   00:07  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:00  -> (00:00 left)
# Creating Associations graph... DONE!
# Report sweet_report Report Survey-1.html was generated! NOTEBOOK/COLAB USERS: no browser will pop up, the report is saved in your notebook/colab files.

# %%
df1 = sv.compare(df[102:], df[:102])
df1.show_html('Compare Survey-1.html')
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-12f25e85b2a1> in <module>
# ----> 1 df1 = sv.compare(df[102:], df[:102])
#       2 df1.show_html('Compare Survey-1.html')
#
# ~\anaconda3\lib\site-packages\sweetviz\sv_public.py in compare(source, compare, target_feat, feat_cfg, pairwise_analysis)
#      21             pairwise_analysis: str = 'auto'):
#      22     report = sweetviz.DataframeReport(source, target_feat, compare,
# ---> 23                                       pairwise_analysis, feat_cfg)
#      24     return report
#      25
#
# ~\anaconda3\lib\site-packages\sweetviz\dataframe_report.py in __init__(self, source, target_feature_name, compare, pairwise_analysis, fc)
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
# Out:
# Summarizing dataframe:             |                         | [  0%]   00:28  -> (? left)
# Imported AutoViz_Class version: 0.0.68. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
#
# To remove previous versions, perform 'pip uninstall autoviz'

# %%
df = AV.AutoViz('Survey-1.csv')
# Out:
# Shape of your Data Set: (62, 14)
# Classifying variables in data set...
#     14 Predictors classified...
#         This does not include the Target column(s)
#     1 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 15
# Could not draw Distribution Plot
# Number of Categorical and Continuous Vars exceeds limit, hence no Bar Plots
# Time to run AutoViz (in seconds) = 3.258

# %%
df = AV.AutoViz('Survey-1.csv', depVar='highway-mpg')
# Out:
# Shape of your Data Set: (62, 14)
# Classifying variables in data set...
#     14 Predictors classified...
#         This does not include the Target column(s)
#     1 variables removed since they were ID or low-information variables
# Could not find given target var in data set. Please check input
# Not able to read or load file. Please check your inputs and try again...

# %% [markdown]
# ### Detergents_Paper is highly correlated with Grocery
# ### Grocery is highly correlated with Detergents_Paper
