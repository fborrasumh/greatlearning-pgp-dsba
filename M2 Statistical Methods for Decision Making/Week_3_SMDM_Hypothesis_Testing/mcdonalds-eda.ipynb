# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 
import math
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)


# from wordcloud import WordCloud, STOPWORDS

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra
import matplotlib 
import matplotlib.pyplot as plt
import sklearn
# %matplotlib inline
import matplotlib.pyplot as plt 
plt.rcParams["figure.figsize"] = [15, 7]
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# %%
df = pd.read_csv('Mcdonald.csv')

# %% [markdown]
# #### 1.	Plot graphically which food categories have the highest and lowest varieties

# %% [markdown]
# Answer:
# ##### highest food categories: Coffee & Tea
# ##### lowest food categories: Salad

# %%
df.Category.value_counts().plot.bar();

# %%
df.groupby('Category')['Item'].count().sort_values(ascending=False).head(1)
# Out:
# Category
# Coffee & Tea    95
# Name: Item, dtype: int64

# %%
df.groupby('Category')['Item'].count().sort_values(ascending=False).tail(1)
# Out:
# Category
# Salads    6
# Name: Item, dtype: int64

# %% [markdown]
# #### 2.	Which all variables have an outlier?

# %% [markdown]
# Answer
# ####  below variables have an outlier
# - Calories
# - Calories from Fat
# - Total Fat
# - Total Fat (% Daily Value)
# - Cholesterol
# - Cholesterol (% Daily Value)
# - Sodium
# - Sodium (% Daily Value)
# - Carbohydrates
# - Carbohydrates (% Daily Value)
# - Sugars
# - Protein
# - Vitamin A (% Daily Value)
# - Vitamin C (% Daily Value)
# - Calcium (% Daily Value)
# - Iron (% Daily Value)

# %%
ax = sns.boxplot(data=df, orient="h")

# %% [markdown]
# #### 3.	Which variables have the highest correlation? Plot them and find out the value?

# %%
corrmat = df.corr() 
  
cg = sns.clustermap(corrmat, cmap ="YlGnBu", linewidths = 0.5,vmin=0, vmax=1,annot=True,figsize=(15, 13)); 
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0) 

cg

# %% [markdown]
# ### 4.	Which category contributes to the maximum % of Cholesterol in a diet (% daily value)?

# %%
df.groupby('Category')['Cholesterol (% Daily Value)'].sort_values(ascending=False).head(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-9f6f896ac282> in <module>
# ----> 1 df.groupby('Category')['Cholesterol (% Daily Value)'].sort_values(ascending=False).head(20)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'sort_values'

# %% [markdown]
# ### 5.	Which item contributes maximum to the Sodium intake?

# %%
df.groupby(['Item'])['Sodium'].sum().sort_values(ascending=False).head(1)
# Out:
# Item
# Chicken McNuggets (40 piece)    3600
# Name: Sodium, dtype: int64

# %% [markdown]
# ### 6.	Which 4 food items contain the most amount of Saturated Fat

# %%
df.groupby(['Item'])['Saturated Fat'].sum().sort_values(ascending=False).head(4)
# Out:
# Item
# Big Breakfast with Hotcakes (Large Biscuit)    20.0
# Chicken McNuggets (40 piece)                   20.0
# McFlurry with M&M’s Candies (Medium)           20.0
# Frappé Chocolate Chip (Large)                  20.0
# Name: Saturated Fat, dtype: float64
